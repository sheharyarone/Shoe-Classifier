# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Obtaining dependency information for torchvision!=0.13.0,>=0.8.1 from https://files.pythonhosted.org/packages/f9/e6/3c821e7417acd82df89e39f09156ce80d58817b5b4b1ac5453b522bc5dd4/torchvision-0.16.2-cp311-cp311-win_amd64.whl.metadata
#   Using cached torchvision-0.16.2-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...
# Using cached torchvision-0.16.2-cp311-cp311-win_amd64.whl (1.1 MB)
# ...

# %%
# !python detect.py --weights weights/weights_50_epochs.pt --conf 0.2 --source test_data/hello.mp4 --save-cropped
# Out:
# Namespace(weights=['weights/weights_50_epochs.pt'], source='test_data/hello.mp4', img_size=640, conf_thres=0.2, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False, save_cropped=True)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# video 1/1 (1/161) d:\DIP Project\yolov7-main\test_data\hello.mp4: 2 shoess, Done. (2369.4ms) Inference, (4.0ms) NMS
# video 1/1 (2/161) d:\DIP Project\yolov7-main\test_data\hello.mp4: 2 shoess, Done. (2270.4ms) Inference, (6.6ms) NMS
# video 1/1 (3/161) d:\DIP Project\yolov7-main\test_data\hello.mp4: 2 shoess, Done. (2457.6ms) Inference, (2.0ms) NMS
# ...
